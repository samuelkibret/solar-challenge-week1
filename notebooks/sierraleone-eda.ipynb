# %% [markdown]
# #Sierraleone Analysis

# %% [markdown]
# #Installing libraries

# %%
# %pip install panda
# %pip install seaborn
# %pip install matplotlib
# %pip install numpy
# %pip install scipy
# Out:
# Requirement already satisfied: panda in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: setuptools in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from panda) (80.7.1)
# Requirement already satisfied: requests in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from panda) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from requests->panda) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from requests->panda) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from requests->panda) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from requests->panda) (2025.4.26)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (2.2.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages (from scipy) (2.2.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##Read into DF

# %%
import pandas as pd

df = pd.read_csv("../data/raw/sierraleone-bumbuna.csv")
df.head()
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# #Summary

# %%
df.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# 25%         0.000000      23.100000      68.700000       0.000000
# 50%         3.400000      25.300000      85.400000       0.800000
# 75%       345.400000      29.400000      96.700000       2.000000
# max      1473.000000      39.900000     100.000000      19.200000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        1.691606       0.363823     133.044668       7.172220
# std         1.617053       0.295000     114.284792       7.535093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.600000       0.400000     161.500000       6.200000
# 75%         2.600000       0.600000     234.100000      12.000000
# max        23.900000       4.100000     360.000000      98.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      999.876469       0.000967       0.004806      32.504263
# std         2.104419       0.031074       0.047556      12.434899
# min       993.000000       0.000000       0.000000      10.700000
# 25%       999.000000       0.000000       0.000000      23.500000
# 50%      1000.000000       0.000000       0.000000      26.600000
# 75%      1001.000000       0.000000       0.000000      40.900000
# max      1006.000000       1.000000       2.400000      72.800000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.593091       NaN
# std        12.009161       NaN
# min        11.100000       NaN
# 25%        23.800000       NaN
# 50%        26.900000       NaN
# 75%        41.300000       NaN
# max        70.400000       NaN

# %% [markdown]
# List any columns with over 5% null value

# %%
missing_values = df.isna().sum()
print(missing_values)

# Filter columns where missing values exceed 5% of the DataFrame length
threshold = 0.05 * len(df)
columns_with_many_nans = missing_values[missing_values > threshold].index

print(columns_with_many_nans)
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
# Index(['Comments'], dtype='object')

# %% [markdown]
# #Outlier detection and basic cleaning

# %%
key_columns = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']
missing_in_key_cols = df[key_columns].isna().sum()
print("Missing values in key columns:")
print(missing_in_key_cols)
# Out:
# Missing values in key columns:
# GHI       0
# DNI       0
# DHI       0
# ModA      0
# ModB      0
# WS        0
# WSgust    0
# dtype: int64

# %% [markdown]
# #Z score outlier detection and flagging

# %%
from scipy.stats import zscore
import numpy as np

key_columns = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']

# Recompute Z-scores in case data changed
z_scores = df[key_columns].apply(zscore)

# Flag rows with any absolute Z-score > 3
df['Outlier'] = (np.abs(z_scores) > 3).any(axis=1)

# Preview how many outliers were flagged
print(f"Total flagged outliers: {df['Outlier'].sum()}")
# Out:
# Total flagged outliers: 16292

# %% [markdown]
# #Clip negative irradance to zero

# %%
irradiance_cols = ['GHI', 'DNI', 'DHI']

# Replace negative values with 0
df[irradiance_cols] = df[irradiance_cols].clip(lower=0)

# %% [markdown]
# #Export Data

# %%
df.to_csv("../data/cleaned/sierraleone_clean.csv", index=False)

# %% [markdown]
# #Time Series Analysis

# %%
# Ensure Timestamp is datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Set as index (optional but helpful for time series)
df = df.set_index('Timestamp')

# Plot irradiance & temperature over time
df[['GHI', 'DNI', 'DHI', 'Tamb']].plot(subplots=True, figsize=(12, 8), title='Time Series')
# Out:
# array([<Axes: xlabel='Timestamp'>, <Axes: xlabel='Timestamp'>,
#        <Axes: xlabel='Timestamp'>, <Axes: xlabel='Timestamp'>],
#       dtype=object)

# %% [markdown]
# #Group By Monthly and Hourly

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df['month'] = df['Timestamp'].dt.month
df['hour'] = df['Timestamp'].dt.hour

#monthly

monthly_avg = df.groupby('month')[['GHI', 'DNI', 'DHI', 'Tamb']].mean()

monthly_avg.plot(marker='o', figsize=(10, 6), title='Monthly Averages')
plt.ylabel('Value')
plt.grid(True)
plt.show()

#Hourly

hourly_avg = df.groupby('hour')[['GHI', 'DNI', 'DHI', 'Tamb']].mean()

hourly_avg.plot(marker='o', figsize=(10, 6), title='Average by Hour of Day')
plt.ylabel('Value')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['Timestamp'] = pd.to_datetime(df['Timestamp'])
#       2 df['month'] = df['Timestamp'].dt.month
#       3 df['hour'] = df['Timestamp'].dt.hour
#
# File /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /workspaces/solar-challenge-week1/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Timestamp'

# %% [markdown]
# #Cleaned Impact

# %%
# Compare ModA and ModB before vs after cleaning
df.groupby('Cleaning')[['ModA', 'ModB']].mean().plot(kind='bar', title='Effect of Cleaning')
# Out:
# <Axes: title={'center': 'Effect of Cleaning'}, xlabel='Cleaning'>

# %% [markdown]
# #Heatmap of Correlations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_cols = ['GHI', 'DNI', 'DHI', 'TModA', 'TModB']
sns.heatmap(df[corr_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# Scatter plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define pairs of variables for x and y axes
scatter_pairs = [
    ('WS', 'GHI'),
    ('WSgust', 'GHI'),
    ('WD', 'GHI'),
    ('RH', 'Tamb'),
    ('RH', 'GHI')
]

# Loop over each pair and generate scatter plot
for x_var, y_var in scatter_pairs:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(data=df, x=x_var, y=y_var)
    plt.title(f"{x_var} vs {y_var}")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #Windrose

# %%
import numpy as np

# Bin wind directions into 30° intervals
df['WD_bin'] = (df['WD'] // 30) * 30
wind_df = df.groupby('WD_bin')['WS'].mean().reset_index()

# Convert degrees to radians
angles = np.deg2rad(wind_df['WD_bin'])
values = wind_df['WS']

plt.figure(figsize=(6,6))
ax = plt.subplot(111, polar=True)
bars = ax.bar(angles, values, width=np.deg2rad(30), color='skyblue', edgecolor='black')

ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title("Wind Rose (Average WS by WD)")
plt.show()

# %% [markdown]
# #Histogram

# %%
df[['GHI', 'WS']].hist(bins=30, figsize=(10, 4), layout=(1, 2))
# Out:
# array([[<Axes: title={'center': 'GHI'}>, <Axes: title={'center': 'WS'}>]],
#       dtype=object)

# %% [markdown]
# #RH effect through scatterplot

# %%
sns.scatterplot(data=df, x='RH', y='Tamb')
sns.scatterplot(data=df, x='RH', y='GHI')
# Out:
# <Axes: xlabel='RH', ylabel='Tamb'>

# %% [markdown]
# #Bubble chart with size =RH

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['GHI'], df['Tamb'], s=df['RH'], alpha=0.5, c='blue')
plt.xlabel("GHI (W/m²)")
plt.ylabel("Ambient Temp (°C)")
plt.title("GHI vs Tamb (Bubble size = RH)")
# Out:
# Text(0.5, 1.0, 'GHI vs Tamb (Bubble size = RH)')
